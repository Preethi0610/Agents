# %%
# Start with imports 

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
#load the env variables
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
ollama_api_key = os.getenv('OLLAMA_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if ollama_api_key:
    print(f"Ollama API Key exists and begins {ollama_api_key[:4]}")
else:
    print("Ollama API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_
# Ollama API Key exists and begins olla

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are the nonpartisan chief policy advisor for a mid-sized coastal city of 500,000 facing three simultaneous crises: (1) a fast-moving infectious respiratory disease causing rising hospitalizations with limited vaccine supply, (2) repeated coastal flooding making 15% of residential neighborhoods intermittently uninhabitable, and (3) a sudden automation-driven layoff wave pushing 40,000 people out of work. The city's one-time emergency fund equals roughly the full-cost implementation of two evidence-based medium-term (2–5 year) interventions but not all three. For each crisis you may propose scalable short-term triage measures and one medium-term intervention; you must choose which two medium-term interventions to fund fully and which to defer. Provide: (a) which two medium-term interventions you would fund and why, including expected benefits, harms, equity impacts, and plausible numerical estimates of outcomes over 5 years with uncertainty ranges and probabilities for success; (b)
# ...

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a compact, policy-planning package you can use in a council brief or briefings with senior staff. It assumes a city of about 500,000 residents, three concurrent crises, and a one-time emergency fund roughly equal to the full cost of two evidence-based medium-term interventions (2–5 years) but not all three.
#
# A. The two medium-term interventions you fund fully (and why)
#
# Intervention A – Flood-resilience infrastructure (coastal protection, floodproofing, and critical infrastructure elevation)
# - What it is: Build/upgrade physical defenses (seawalls, elevating key public facilities, floodproofing essential housing and utilities, drainage upgrades, and, where appropriate, buyouts or buy-downs to reduce exposure). Prioritize 15% of residential neighborhoods most repeatedly uninhabitable, with phased implementation and local labor agreements to maximize local employment.
# ...

# %%
#here instance creation of groq using OpenAI
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "llama-3.3-70b-versatile"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Introduction:**
#
# As the nonpartisan chief policy advisor for a mid-sized coastal city facing three simultaneous crises, I will provide a comprehensive plan to address these challenges. The plan includes funding two medium-term interventions, implementing short-term triage measures for the deferred crisis, requesting key data, utilizing statistical models, tracking metrics, and acknowledging potential biases.
#
# **(a) Funded Medium-Term Interventions:**
#
# I would fund the medium-term interventions for the infectious respiratory disease and coastal flooding.
#
# 1. **Infectious Respiratory Disease:**
#    - Intervention: Implement a comprehensive vaccination and contact tracing program.
#    - Expected Benefits: Reduce hospitalizations by 30% (20-40%) and deaths by 25% (15-35%) over 5 years.
#    - Harms: Potential vaccine side effects, unequal access to vaccines.
#    - Equity Impacts: Prioritize vulnerable populations, such as low-income and minority communities.
# ...

# %% [markdown]
# ## Using Ollama for the next cell
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# can install ollama here -  https://ollama.com
#
# visit here http://localhost:11434 and see the message "Ollama is running"

# %%
import subprocess
result = subprocess.run(['/usr/local/bin/ollama', 'pull', 'llama3.2'], 
                      capture_output=True, text=True)
print(result.stdout)

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Medium-term Interventions:**
#
# Given the city's constraints and multiple crises, I would prioritize funding two medium-term interventions over the third. The chosen interventions aim to address multiple crises simultaneously while minimizing harm and maximizing benefits.
#
# 1. **Funding:** Vaccine distribution expansion for all residents, especially vulnerable populations (e.g., hospitalization support for seniors, people with chronic conditions) and low-income communities.
#    - Expected benefit: Reduce hospitalization rates due to infectious respiratory disease.
#    - Harms: Potential vaccine hesitation, inequality in vaccine access.
#    - Equity impacts: Increasing access to vaccines for marginalized groups can help mitigate health disparities.
#
# 2. **Funding:** Coastal resilience infrastructure upgrades, focusing on flood mitigation and adaptation strategies (e.g., green roofs, upgraded storm drains).
# ...

# %%
print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'llama-3.3-70b-versatile', 'llama3.2']
# ...

# %%
#zip is used to combine two lists into a single list of tuples, means it will take one element from each list and pair them together
#("GPT-4", "ans1")
#("Claude", "ans2")
#("Groq", "ans3")
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Below is a compact, policy-planning package you can use in a council brief or briefings with senior staff. It assumes a city of about 500,000 residents, three concurrent crises, and a one-time emergency fund roughly equal to the full cost of two evidence-based medium-term interventions (2–5 years) but not all three.
#
# A. The two medium-term interventions you fund fully (and why)
#
# Intervention A – Flood-resilience infrastructure (coastal protection, floodproofing, and critical infrastructure elevation)
# - What it is: Build/upgrade physical defenses (seawalls, elevating key public facilities, floodproofing essential housing and utilities, drainage upgrades, and, where appropriate, buyouts or buy-downs to reduce exposure). Prioritize 15% of residential neighborhoods most repeatedly uninhabitable, with phased implementation and local labor agreements to maximize local employment.
# ...

# %% [markdown]
# format for the together:
#
# #Response from competitor 1
#
# direct answer
#
# #Response from competitor 2
#
# direct answer
#
# #Response from competitor 3
#
# direct answer

# %%
together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a compact, policy-planning package you can use in a council brief or briefings with senior staff. It assumes a city of about 500,000 residents, three concurrent crises, and a one-time emergency fund roughly equal to the full cost of two evidence-based medium-term interventions (2–5 years) but not all three.
#
# A. The two medium-term interventions you fund fully (and why)
#
# Intervention A – Flood-resilience infrastructure (coastal protection, floodproofing, and critical infrastructure elevation)
# - What it is: Build/upgrade physical defenses (seawalls, elevating key public facilities, floodproofing essential housing and utilities, drainage upgrades, and, where appropriate, buyouts or buy-downs to reduce exposure). Prioritize 15% of residential neighborhoods most repeatedly uninhabitable, with phased implementation and local labor agreements to maximize local employment.
# ...

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 3 competitors.
# Each model has been given this question:
#
# ...

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2", "3"]}

# %%
results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: llama-3.3-70b-versatile
# Rank 3: llama3.2

# %% [markdown]
# ## Commercial implications:
# These kinds of patterns - to send a task to multiple models, and evaluate results, are common where you need to improve the quality of your LLM response. This approach can be universally applied to business projects where accuracy is critical.
